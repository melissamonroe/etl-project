# %%
from matplotlib import pyplot as plt
import numpy as np
import scipy.stats as stats
import pandas as pd

# Project defined modules
import config
import visualization as viz

# %%
def list_average(my_list): 
    return sum(my_list) / len(my_list)

# %%
# Create visualization object
visuals = viz.Visualizer()
base_df = visuals.get_clean_data()
base_df.head(5)
# Out:
#       data_id                                      listing_title  \
# 0  7278244211           Dog Park, In-Unit Laundry, Extra storage
# 1  7280806990  Dual Master Layout, Detached Garage, Newly Ren...
# 2  7278515816  55+ Community~ 2 BD, Dual Masters, Discounted ...
# 3  7277910674  1 Bed - 1 Bath Huge Kitchen Island + WD + Walk...
# 4  7279719841  1B/1B 🏡 55+ Community! Virtual Tours and Move ...
#
#    listing_price listing_addrlocality listing_addrzip listing_bath  \
# 0           2095             Carlsbad           92009            1
# 1           2920            San Diego           92121            2
# 2           1575            Escondido           92033            2
# 3           2030           San Marcos           92079            1
# 4           1437            Escondido           92033            1
#
#   listing_bed listing_bedbath listing_latitude listing_longitude  listing_sqft
# 0           1       1BR / 1Ba        33.077861       -117.234826           679
# ...

# %%
base_df.sort_values(by=['listing_price'], ascending=True).head(5)
# Out:
#          data_id                                      listing_title  \
# 3702  7273400891  SureStay by Bestwestern Hotel-Weekly rate star...
# 8395  7281458635  Playa hermosa Ensenada. Next to town. Private ...
# 918   7274493738  Do you work in the Agriculture and Need Housin...
# 919   7274490809  FARM WORKER APARTMENTS! Join the Interest List...
# 3576  7278399534          RV Spaces For Rent low space rent 50 amps
#
#       listing_price listing_addrlocality listing_addrzip listing_bath  \
# 3702            475             El Cajon           92022            1
# 8395            500               Tecate           91987            1
# 918             544            Escondido           92033            1
# 919             544            Escondido           92033            1
# 3576            557            Boulevard           91905            1
#
#      listing_bed listing_bedbath listing_latitude listing_longitude  \
# ...

# %%
base_df.sort_values(by=['listing_price'], ascending=False).head(5)
# Out:
#          data_id                                  listing_title  \
# 1740  7278890292                DREAM HOME FISRT TIME FOR LEASE
# 800   7280169186  Your new home awaits! Call Today for Details.
# 281   7278890580                             LUXURY LIFE STYLE!
# 283   7278890472                    YOUR DREAM HOME & FURNISHED
# 5348  7280149658              LEASE OPTION? TERMS - SPECTACULAR
#
#       listing_price listing_addrlocality listing_addrzip listing_bath  \
# 1740          30000      Rancho Santa Fe           92091
# 800           23275             Carlsbad           92018            2
# 281           18500         Solana Beach           92075            5
# 283           18000             La Jolla           92093            7
# 5348          16000                Poway           92074            7
#
#      listing_bed listing_bedbath listing_latitude listing_longitude  \
# 1740           8      8BR / 9+Ba        33.005000       -117.215700
# ...

# %%
base_df.sort_values(by=['listing_sqft'], ascending=False).head()
# Out:
#          data_id                                      listing_title  \
# 5938  7279829067  Low Dep. & Low Rents. Some Hardwood Floors. Wa...
# 1740  7278890292                    DREAM HOME FISRT TIME FOR LEASE
# 3621  7278316425  2bed 2bath for rent in El Cajon - Fully remodeled
# 5348  7280149658                  LEASE OPTION? TERMS - SPECTACULAR
# 813   7280151435              LEASE OPTION? TERMS?  VIEWS  GORGEOUS
#
#       listing_price listing_addrlocality listing_addrzip listing_bath  \
# 5938           2099        Spring Valley           91977            1
# 1740          30000      Rancho Santa Fe           92091
# 3621           1900             El Cajon           92020            2
# 5348          16000                Poway           92074            7
# 813            8500              La Mesa           91941            7
#
#      listing_bed listing_bedbath listing_latitude listing_longitude  \
# 5938           2       2BR / 1Ba        32.736595       -116.971649
# ...

# %%
base_df.sort_values(by=['listing_sqft'], ascending=True).head()
# Out:
#          data_id                                      listing_title  \
# 6555  7279410716  Everything you need within minutes of your gor...
# 6885  7275672817  The Nola! Beautiful Studio in San Yisdro! 1/2 ...
# 4316  7280726073  Granny-flat Studio Detached: ALL Utilities+Lau...
# 5005  7278278426         Modern Studio in the Heart of East Village
# 5313  7280193518  Move in today! Micro studios in Downtown San D...
#
#       listing_price listing_addrlocality listing_addrzip listing_bath  \
# 6555           1795            San Diego           92112            1
# 6885           1050           San Ysidro           92173            1
# 4316           1275            San Diego           92116            1
# 5005           1545            San Diego           92187            1
# 5313           1545            San Diego           92187            1
#
#      listing_bed listing_bedbath listing_latitude listing_longitude  \
# ...

# %%
base_df.dtypes
# Out:
# data_id                 object
# listing_title           object
# listing_price            int64
# listing_addrlocality    object
# listing_addrzip         object
# listing_bath            object
# listing_bed             object
# listing_bedbath         object
# listing_latitude        object
# listing_longitude       object
# listing_sqft             int64
# dtype: object

# %%
grouped_zip_df = base_df.groupby(["listing_addrzip"])
grouped_zip_df.head()
# Out:
#          data_id                                      listing_title  \
# 0     7278244211           Dog Park, In-Unit Laundry, Extra storage
# 1     7280806990  Dual Master Layout, Detached Garage, Newly Ren...
# 2     7278515816  55+ Community~ 2 BD, Dual Masters, Discounted ...
# 3     7277910674  1 Bed - 1 Bath Huge Kitchen Island + WD + Walk...
# 4     7279719841  1B/1B 🏡 55+ Community! Virtual Tours and Move ...
# ...          ...                                                ...
# 7806  7278023310                            4br Fully Equipped Home
# 8228  7281098400  Remodeled Hillside Home Private Quiet Close 3 ...
# 8238  7276478747     Beautiful Single Family Home in Emerald Hills!
# 8268  7281431428  New furnished view home downtown La Jolla, uti...
# 8395  7281458635  Playa hermosa Ensenada. Next to town. Private ...
#
#       listing_price listing_addrlocality listing_addrzip listing_bath  \
# 0              2095             Carlsbad           92009            1
# ...

# %%
# mean, median, variance, standard deviation, and SEM of the listing_price 
mean_listing_price = grouped_zip_df["listing_price"].mean()
zip_count = grouped_zip_df["listing_addrzip"].count()

# Assemble the resulting series into a single summary dataframe.

summary_stats_df = pd.DataFrame(
    {"Average List Price": mean_listing_price,
    "Listing Count": zip_count,
    "Location": grouped_zip_df["listing_addrlocality"].unique(),
    "Zip Code": grouped_zip_df["listing_addrzip"].unique(),
    "Location (Zip)": grouped_zip_df["listing_addrlocality"].unique() + " " + grouped_zip_df["listing_addrzip"].unique()
    })
summary_stats_df
# Out:
#                  Average List Price  Listing Count         Location Zip Code  \
# listing_addrzip
# 20011                   1835.000000              1     [Washington]  [20011]
# 67340                   4150.000000              2        [Dearing]  [67340]
# 89173                   1126.500000              2      [Las Vegas]  [89173]
# 91901                   1450.000000              1         [Alpine]  [91901]
# 91902                   2076.105263             19         [Bonita]  [91902]
# ...                             ...            ...              ...      ...
# 92198                   2365.466667             15      [San Diego]  [92198]
# 92199                   2303.280000             25      [San Diego]  [92199]
# 92531                   2400.000000              1  [Lake Elsinore]  [92531]
# 92593                   1842.222222             27       [Temecula]  [92593]
# 93437                   2150.000000              1         [Lompoc]  [93437]
#
# ...

# %%
summary_stats_highpricezips_df = summary_stats_df.sort_values(by=['Average List Price'], ascending=False).head(20)
summary_stats_lowpricezips_df = summary_stats_df.sort_values(by=['Average List Price'], ascending=True).head(20)
summary_stats_mostlistingszips_df = summary_stats_df.sort_values(by=['Listing Count'], ascending=False).head(20)

# %%
summary_stats_highpricezips_df
# Out:
#                  Average List Price  Listing Count              Location  \
# listing_addrzip
# 92091                  16800.000000              2     [Rancho Santa Fe]
# 92155                   6000.000000              1           [San Diego]
# 67340                   4150.000000              2             [Dearing]
# 92075                   3829.500000             20        [Solana Beach]
# 92093                   3621.961538             26            [La Jolla]
# 92029                   3500.833333              6           [Escondido]
# 92003                   3250.000000              2             [Bonsall]
# 92014                   3024.560606             66             [Del Mar]
# 92147                   3007.436364             55           [San Diego]
# 92052                   2951.564103             39           [Oceanside]
# 92130                   2885.650000             20           [San Diego]
# 92007                   2871.145833             48  [Cardiff By The Sea]
# ...

# %%
summary_stats_lowpricezips_df
# Out:
#                  Average List Price  Listing Count          Location Zip Code  \
# listing_addrzip
# 91987                    500.000000              1          [Tecate]  [91987]
# 91905                    557.000000              1       [Boulevard]  [91905]
# 89173                   1126.500000              2       [Las Vegas]  [89173]
# 92036                   1258.333333              3          [Julian]  [92036]
# 91935                   1375.000000              1           [Jamul]  [91935]
# 91908                   1439.500000              2          [Bonita]  [91908]
# 91901                   1450.000000              1          [Alpine]  [91901]
# 92030                   1471.326531             49       [Escondido]  [92030]
# 92106                   1485.000000              2       [San Diego]  [92106]
# 92021                   1488.809524             21        [El Cajon]  [92021]
# 92065                   1489.615385             13          [Ramona]  [92065]
# ...

# %%
summary_stats_mostlistingszips_df
# Out:
#                  Average List Price  Listing Count       Location Zip Code  \
# listing_addrzip
# 92033                   1861.419023            389    [Escondido]  [92033]
# 92122                   2417.017621            227    [San Diego]  [92122]
# 92187                   2548.483871            217    [San Diego]  [92187]
# 92054                   1995.459459            185    [Oceanside]  [92054]
# 92085                   2011.718232            181        [Vista]  [92085]
# 92079                   2277.203390            177   [San Marcos]  [92079]
# 91909                   1758.262500            160  [Chula Vista]  [91909]
# 92056                   2040.094937            158    [Oceanside]  [92056]
# 92112                   2629.366412            131    [San Diego]  [92112]
# 91943                   1994.138462            130      [La Mesa]  [91943]
# 91911                   1976.474138            116  [Chula Vista]  [91911]
# ...

# %%
mean_highprices = []
locations_highprices = []
zipcodes_highprices = []

for m in summary_stats_highpricezips_df['Average List Price']:
    mean_highprices.append(m)
for l in summary_stats_highpricezips_df['Location (Zip)']:
    locations_highprices.append(l)        
for z in summary_stats_highpricezips_df['Zip Code']:
    zipcodes_highprices.append(z)

# %%
x_axis = np.arange(0, len(locations_highprices))
tick_locations = []
for x in x_axis:
    tick_locations.append(x)
    
fig, ax = plt.subplots(figsize=(12,8)) # set the size that you'd like 
fig.subplots_adjust(bottom=0.4)
for item in ([ax.title, ax.xaxis.label, ax.yaxis.label] +
             ax.get_xticklabels() + ax.get_yticklabels()):
    item.set_fontsize(14)
fig.suptitle('Top 20 Highest Average Rental Listing Price', fontsize=20)

plt.xlabel("Zip Code")
plt.ylabel("Average Rental Listing Price ($)")

plt.xlim(-0.75, len(locations_highprices)-.25)
plt.ylim(0, max(mean_highprices) + 1000)

plt.bar(x_axis,mean_highprices, facecolor="#097392", alpha=0.75, align="center")
plt.xticks(tick_locations, locations_highprices, rotation=90)
plt.savefig("../resources/images/fig01_top20averageprice.png")
plt.show()

# %%
mean_lowprices = []
locations_lowprices = []
zipcodes_lowprices = []

for m in summary_stats_lowpricezips_df['Average List Price']:
    mean_lowprices.append(m)
for l in summary_stats_lowpricezips_df['Location (Zip)']:
    locations_lowprices.append(l)        
for z in summary_stats_lowpricezips_df['Zip Code']:
    zipcodes_lowprices.append(z)

# %%
x_axis = np.arange(0, len(locations_lowprices))
tick_locations = []
for x in x_axis:
    tick_locations.append(x)
    
fig, ax = plt.subplots(figsize=(12,8)) # set the size that you'd like 
fig.subplots_adjust(bottom=0.4)
for item in ([ax.title, ax.xaxis.label, ax.yaxis.label] +
             ax.get_xticklabels() + ax.get_yticklabels()):
    item.set_fontsize(14)
fig.suptitle('Lowest Average Rental Listing Price', fontsize=20)

plt.xlabel("Location and Zip Code")
plt.ylabel("Average Rental Listing Price ($)")

plt.xlim(-0.75, len(locations_lowprices)-.25)
plt.ylim(0, max(mean_lowprices) + 1000)

plt.bar(x_axis, mean_lowprices, facecolor=config.orangered, alpha=0.75, align="center")
plt.xticks(tick_locations, locations_lowprices, rotation=90)
plt.savefig("../resources/images/fig02_bottom20averageprice.png")
plt.show()

# %%
"""
# Histogram Plot of Data
plt.subplot(2, 1, 2)
plt.hist(population, 20, density=True, alpha=0.7, label="population")
plt.hist(sample, 20, density=True, alpha=0.7, label="sample")
plt.axvline(population.mean(), color='k', linestyle='dashed', linewidth=1)
plt.axvline(sample.mean(), color='k', linestyle='dashed', linewidth=1)
plt.legend()  
"""
# Out:
# '\n# Histogram Plot of Data\nplt.subplot(2, 1, 2)\nplt.hist(population, 20, density=True, alpha=0.7, label="population")\nplt.hist(sample, 20, density=True, alpha=0.7, label="sample")\nplt.axvline(population.mean(), color=\'k\', linestyle=\'dashed\', linewidth=1)\nplt.axvline(sample.mean(), color=\'k\', linestyle=\'dashed\', linewidth=1)\nplt.legend()  \n'

# %%
listprices = []

for lp in base_df['listing_price']: 
    if (lp < 6000):
        listprices.append(lp)

print(f'Total number of list prices analyzed: {len(listprices)}')  
print(f'Average listing price accross all zip codes: ${round(list_average(listprices),0)}')  
print(f'Highest list price all zip codes ${max(listprices)}')
print(f'Lowest list price all zip codes ${min(listprices)}')
# Out:
# Total number of list prices analyzed: 5525
# Average listing price accross all zip codes: $2143.0
# Highest list price all zip codes $5900
# Lowest list price all zip codes $475

# %%
# Histogram Plot of Data
fig, ax = plt.subplots(figsize=(10,6)) # set the size that you'd like 
fig.suptitle('Histogram of list prices for all zip codes', fontsize=20)
plt.xlabel("List Price ($)")

plt.subplot(1,1,1)
plt.hist(listprices, 120, density=True, alpha=0.7,color=config.lightgreen, label="Listing Prices (all zip codes)")
plt.axvline(list_average(listprices), color='k', linestyle='dashed', linewidth=1)
plt.savefig("../resources/images/fig05_listinghistallzips.png")
plt.legend() 



plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
base_df
# Out:
#          data_id                                      listing_title  \
# 0     7278244211           Dog Park, In-Unit Laundry, Extra storage
# 1     7280806990  Dual Master Layout, Detached Garage, Newly Ren...
# 2     7278515816  55+ Community~ 2 BD, Dual Masters, Discounted ...
# 3     7277910674  1 Bed - 1 Bath Huge Kitchen Island + WD + Walk...
# 4     7279719841  1B/1B 🏡 55+ Community! Virtual Tours and Move ...
# ...          ...                                                ...
# 9049  7281626371  $300 off first months rent!! Updated 2x2 in gr...
# 9052  7281620514                                    Wait List Open!
# 9053  7281619617                              GET ON OUR WAITLIST!!
# 9054  7281618679                               Get On Our Waitlist!
# 9068  7281474173               House for rent National City w Solar
#
#       listing_price listing_addrlocality listing_addrzip listing_bath  \
# 0              2095             Carlsbad           92009            1
# ...

# %%
# mean, median, variance, standard deviation, and SEM of the listing_price 
zip_count = grouped_zip_df["listing_addrzip"].count()

# Assemble the resulting series into a single summary dataframe.

summary_stats_df = pd.DataFrame(
    {"Zip Listing Count": zip_count,
    "Location": grouped_zip_df["listing_addrlocality"].unique(),
    "Zip Code": grouped_zip_df["listing_addrzip"].unique(),
    "Location (Zip)": grouped_zip_df["listing_addrlocality"].unique() + " " + grouped_zip_df["listing_addrzip"].unique()
    })
summary_stats_df
# Out:
#                  Zip Listing Count         Location Zip Code  \
# listing_addrzip
# 20011                            1     [Washington]  [20011]
# 67340                            2        [Dearing]  [67340]
# 89173                            2      [Las Vegas]  [89173]
# 91901                            1         [Alpine]  [91901]
# 91902                           19         [Bonita]  [91902]
# ...                            ...              ...      ...
# 92198                           15      [San Diego]  [92198]
# 92199                           25      [San Diego]  [92199]
# 92531                            1  [Lake Elsinore]  [92531]
# 92593                           27       [Temecula]  [92593]
# 93437                            1         [Lompoc]  [93437]
#
#                         Location (Zip)
# listing_addrzip
# 20011               [Washington 20011]
# 67340                  [Dearing 67340]
# 89173                [Las Vegas 89173]
# ...

# %%
listing_92033_df = base_df.loc[(base_df['listing_addrzip'] == '92033') & (base_df['listing_price'] < 4000)]
listing_92033_prices = listing_92033_df['listing_price']

len(listing_92033_prices)
print(f'Total number of list prices in 92033 (Escondido): {len(listing_92033_prices)}')  
print(f'Average listing price accross 92033 (Escondido): ${round(list_average(listing_92033_prices),0)}')  
print(f'Highest list price in 92033 (Escondido) ${max(listing_92033_prices)}')
print(f'Lowest list price in 92033 (Escondido) ${min(listing_92033_prices)}')
# Out:
# Total number of list prices in 92033 (Escondido): 388
# Average listing price accross 92033 (Escondido): $1828.0
# Highest list price in 92033 (Escondido) $3950
# Lowest list price in 92033 (Escondido) $544

# %%
# Histogram Plot of Data
fig, ax = plt.subplots(figsize=(10,6)) # set the size that you'd like 
fig.suptitle('Histogram of list prices 92033 (Encinitas)', fontsize=20)
plt.xlabel("List Price ($)")

plt.subplot(1,1,1)
plt.hist(listing_92033_prices, 80, density=True, alpha=0.7,color=config.greenblue, label="Listing Prices 92033 (Escondido)")
plt.axvline(list_average(listing_92033_prices), color='k', linestyle='dashed', linewidth=1)
plt.savefig("../resources/images/fig07_listinghist92033zip.png")
plt.legend()  
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
