# %%
from matplotlib import pyplot as plt
import numpy as np
import scipy.stats as stats
import pandas as pd

# Project defined modules
import config
import visualization as viz

# %%
def list_average(my_list): 
    return sum(my_list) / len(my_list)

# %%
# Create visualization object
visuals = viz.Visualizer()
base_df = visuals.get_clean_data()
base_df.head(5)
# Out:
# 7280330432
# 7280330254
# 7280258044
# 7280257806
# 7278522138
# 7278522299
# 7278706223
# 7278706397
# 7278522046
#       data_id                                      listing_title  \
# 1  7270676228  Rare Rental opportunity Ocean View Roomy 3Br D...
# 2  7270681947  Coming Soon! Rare rental opportunity Ocean Vie...
# 3  7268621225  So Cal pool and hot tub living at its best! 3 ...
# 4  7280856015  55+ 2/bd 1/ba, Flexible Lease Terms Available,...
# 5  7270255048  Smart Apt Located 5 Minutes from Camp Pendleton!!
#
#    listing_price listing_addrlocality listing_addrzip  listing_bath  \
# 1           3895            Oceanside           92052           4.0
# 2           3895            Oceanside           92052           4.0
# 3           3247                Vista           92084           2.0
# 4           1500            Escondido           92033           1.0
# 5           2077            Oceanside           92054           2.0
#
#    listing_bed listing_bedbath  listing_latitude  listing_longitude  \
# 1          3.0     3BR / 3.5Ba         33.190845        -117.377609
# 2          3.0     3BR / 3.5Ba         33.190845        -117.377609
# 3          3.0       3BR / 2Ba         33.224945        -117.230476
# 4          2.0       2BR / 1Ba         33.143531        -117.096653
# 5          2.0       2BR / 2Ba         33.207336        -117.368114
#
#   listing_sqft
# 1         2042
# 2         2042
# 3         1939
# 4          812
# 5          884

# %%
base_df.sort_values(by=['listing_price'], ascending=True).head(5)
# Out:
#          data_id                                      listing_title  \
# 3124  7278094458  SureStay by Bestwestern Hotel-Weekly rate star...
# 6783  7281458635  Playa hermosa Ensenada. Next to town. Private ...
# 1660  7274490809  FARM WORKER APARTMENTS! Join the Interest List...
# 1659  7274493738  Do you work in the Agriculture and Need Housin...
# 2977  7278399534          RV Spaces For Rent low space rent 50 amps
#
#       listing_price listing_addrlocality listing_addrzip  listing_bath  \
# 3124            475             El Cajon           92022           1.0
# 6783            500               Tecate           91987           1.0
# 1660            544            Escondido           92033           1.0
# 1659            544            Escondido           92033           1.0
# 2977            557            Boulevard           91905           1.0
#
#       listing_bed listing_bedbath  listing_latitude  listing_longitude  \
# 3124          1.0       1BR / 1Ba         32.797617        -116.933211
# 6783          2.0       2BR / 1Ba         31.840816        -116.610603
# 1660          1.0       1BR / 1Ba         33.102743        -117.071756
# 1659          2.0       2BR / 1Ba         33.102743        -117.071756
# 2977          1.0       1BR / 1Ba         32.671900        -116.320000
#
#      listing_sqft
# 3124          250
# 6783         3230
# 1660          550
# 1659          650
# 2977         1200

# %%
base_df.sort_values(by=['listing_price'], ascending=False).head(5)
# Out:
#          data_id                                  listing_title  \
# 2278  7278890292                DREAM HOME FISRT TIME FOR LEASE
# 1591  7280169186  Your new home awaits! Call Today for Details.
# 277   7278890580                             LUXURY LIFE STYLE!
# 276   7278890472                    YOUR DREAM HOME & FURNISHED
# 1601  7280148356         LEASE OPTION? 40 ACRES 2:1 HORSES POOL
#
#       listing_price listing_addrlocality listing_addrzip  listing_bath  \
# 2278          30000      Rancho Santa Fe           92091           0.5
# 1591          23275             Carlsbad           92018           2.0
# 277           18500         Solana Beach           92075           5.0
# 276           18000             La Jolla           92093           7.0
# 1601          15000            Escondido           92033           5.0
#
#       listing_bed listing_bedbath  listing_latitude  listing_longitude  \
# 2278          8.0      8BR / 9+Ba          33.00500        -117.215700
# 1591          2.0       2BR / 2Ba          33.15508        -117.348161
# 277           4.0     4BR / 4.5Ba          32.96650        -117.249000
# 276           6.0     6BR / 6.5Ba          32.84550        -117.252100
# 1601          7.0       7BR / 5Ba          33.16050        -117.097800
#
#      listing_sqft
# 2278        11325
# 1591          900
# 277          4482
# 276          4900
# 1601         5100

# %%
base_df.sort_values(by=['listing_sqft'], ascending=False).head()
# Out:
#          data_id                                      listing_title  \
# 2278  7278890292                    DREAM HOME FISRT TIME FOR LEASE
# 3739  7278316425  2bed 2bath for rent in El Cajon - Fully remodeled
# 1598  7280151435              LEASE OPTION? TERMS?  VIEWS  GORGEOUS
# 3117  7281014466           Gorgeous 8 bedrooms custom home for rent
# 1601  7280148356             LEASE OPTION? 40 ACRES 2:1 HORSES POOL
#
#       listing_price listing_addrlocality listing_addrzip  listing_bath  \
# 2278          30000      Rancho Santa Fe           92091           0.5
# 3739           1900             El Cajon           92020           2.0
# 1598           8500              La Mesa           91941           7.0
# 3117           8350              Dearing           67340           4.0
# 1601          15000            Escondido           92033           5.0
#
#       listing_bed listing_bedbath  listing_latitude  listing_longitude  \
# 2278          8.0      8BR / 9+Ba          33.00500         -117.21570
# 3739          2.0       2BR / 2Ba          32.79280         -116.96650
# 1598          6.0       6BR / 7Ba          32.76040         -117.01150
# 3117          8.0     8BR / 3.5Ba          37.13284          -95.78558
# 1601          7.0       7BR / 5Ba          33.16050         -117.09780
#
#      listing_sqft
# 2278        11325
# 3739         8964
# 1598         6100
# 3117         5350
# 1601         5100

# %%
base_df.sort_values(by=['listing_sqft'], ascending=True).head()
# Out:
#          data_id                                      listing_title  \
# 8225  7282168055     Schedule a Tour, Closet Organizers, Work Space
# 7048  7275672817  The Nola! Beautiful Studio in San Yisdro! 1/2 ...
# 5302  7281271115                      At Last! A Place to Call Home
# 5672  7280193518  Move in today! Micro studios in Downtown San D...
# 5267  7278278426         Modern Studio in the Heart of East Village
#
#       listing_price listing_addrlocality listing_addrzip  listing_bath  \
# 8225           3495            San Diego           92187           1.0
# 7048           1050           San Ysidro           92173           1.0
# 5302           1545            San Diego           92187           1.0
# 5672           1545            San Diego           92187           1.0
# 5267           1545            San Diego           92187           1.0
#
#       listing_bed listing_bedbath  listing_latitude  listing_longitude  \
# 8225          1.0       1BR / 1Ba         32.711629        -117.154612
# 7048          0.0       0BR / 1Ba         32.552820        -117.045730
# 5302          0.0       0BR / 1Ba         32.709423        -117.152802
# 5672          0.0       0BR / 1Ba         32.709749        -117.152509
# 5267          0.0       0BR / 1Ba         32.709423        -117.152802
#
#      listing_sqft
# 8225           71
# 7048          180
# 5302          202
# 5672          202
# 5267          202

# %%
base_df.dtypes
# Out:
# data_id                  object
# listing_title            object
# listing_price             int64
# listing_addrlocality     object
# listing_addrzip          object
# listing_bath            float64
# listing_bed             float64
# listing_bedbath          object
# listing_latitude        float64
# listing_longitude       float64
# listing_sqft             object
# dtype: object

# %%
grouped_zip_df = base_df.groupby(["listing_addrzip"])
grouped_zip_df.head()
# Out:
#          data_id                                      listing_title  \
# 1     7270676228  Rare Rental opportunity Ocean View Roomy 3Br D...
# 2     7270681947  Coming Soon! Rare rental opportunity Ocean Vie...
# 3     7268621225  So Cal pool and hot tub living at its best! 3 ...
# 4     7280856015  55+ 2/bd 1/ba, Flexible Lease Terms Available,...
# 5     7270255048  Smart Apt Located 5 Minutes from Camp Pendleton!!
# ...          ...                                                ...
# 8282  7282193772                     DOWNTOWN STUDIOS FOR $1250 !!!
# 8433  7282112939        Remodeled & recently refreshed 3 bed 2 bath
# 8503  7281980678                                 Large Modern House
# 8505  7281966463                    Spanish Mission Hills Home./🔴😉💖
# 8514  7281913432  Luxury Living in The 💜 Of La Jolla! Bright Poo...
#
#       listing_price listing_addrlocality listing_addrzip  listing_bath  \
# 1              3895            Oceanside           92052           4.0
# 2              3895            Oceanside           92052           4.0
# 3              3247                Vista           92084           2.0
# 4              1500            Escondido           92033           1.0
# 5              2077            Oceanside           92054           2.0
# ...             ...                  ...             ...           ...
# 8282           1250            San Diego           92132           1.0
# 8433           1750            San Diego           92114           2.0
# 8503           2000             Calexico           92232           4.0
# 8505            600            Sugarloaf           92386           1.0
# 8514           2212              Anaheim           92807           1.0
#
#       listing_bed listing_bedbath  listing_latitude  listing_longitude  \
# 1             3.0     3BR / 3.5Ba         33.190845        -117.377609
# 2             3.0     3BR / 3.5Ba         33.190845        -117.377609
# 3             3.0       3BR / 2Ba         33.224945        -117.230476
# 4             2.0       2BR / 1Ba         33.143531        -117.096653
# 5             2.0       2BR / 2Ba         33.207336        -117.368114
# ...           ...             ...               ...                ...
# 8282          0.0       0BR / 1Ba         32.709370        -117.162166
# 8433          3.0       3BR / 2Ba         32.705900        -117.052400
# 8503          3.0     3BR / 3.5Ba         32.661153        -115.456020
# 8505          1.0       1BR / 1Ba         34.257897        -116.812820
# 8514          1.0       1BR / 1Ba         33.869736        -117.779661
#
#      listing_sqft
# 1            2042
# 2            2042
# 3            1939
# 4             812
# 5             884
# ...           ...
# 8282          285
# 8433         1154
# 8503         4800
# 8505          700
# 8514          832
#
# [531 rows x 11 columns]

# %%
# mean, median, variance, standard deviation, and SEM of the listing_price 
mean_listing_price = grouped_zip_df["listing_price"].mean()
zip_count = grouped_zip_df["listing_addrzip"].count()

# Assemble the resulting series into a single summary dataframe.

summary_stats_df = pd.DataFrame(
    {"Average List Price": mean_listing_price,
    "Listing Count": zip_count,
    "Location": grouped_zip_df["listing_addrlocality"].unique(),
    "Zip Code": grouped_zip_df["listing_addrzip"].unique(),
    "Location (Zip)": grouped_zip_df["listing_addrlocality"].unique() + " " + grouped_zip_df["listing_addrzip"].unique()
    })
summary_stats_df
# Out:
#                  Average List Price  Listing Count         Location Zip Code  \
# listing_addrzip
# 67340                   5550.000000              3        [Dearing]  [67340]
# 89173                   1137.000000              2      [Las Vegas]  [89173]
# 91901                   1450.000000              1         [Alpine]  [91901]
# 91902                   2007.500000             10         [Bonita]  [91902]
# 91903                   1667.346154             26         [Alpine]  [91903]
# ...                             ...            ...              ...      ...
# 92386                    600.000000              1      [Sugarloaf]  [92386]
# 92531                   2400.000000              1  [Lake Elsinore]  [92531]
# 92593                   1841.290323             31       [Temecula]  [92593]
# 92807                   2212.000000              1        [Anaheim]  [92807]
# 93437                   2150.000000              1         [Lompoc]  [93437]
#
#                         Location (Zip)
# listing_addrzip
# 67340                  [Dearing 67340]
# 89173                [Las Vegas 89173]
# 91901                   [Alpine 91901]
# 91902                   [Bonita 91902]
# 91903                   [Alpine 91903]
# ...                                ...
# 92386                [Sugarloaf 92386]
# 92531            [Lake Elsinore 92531]
# 92593                 [Temecula 92593]
# 92807                  [Anaheim 92807]
# 93437                   [Lompoc 93437]
#
# [128 rows x 5 columns]

# %%
summary_stats_highpricezips_df = summary_stats_df.sort_values(by=['Average List Price'], ascending=False).head(20)
summary_stats_lowpricezips_df = summary_stats_df.sort_values(by=['Average List Price'], ascending=True).head(20)
summary_stats_mostlistingszips_df = summary_stats_df.sort_values(by=['Listing Count'], ascending=False).head(20)

# %%
summary_stats_highpricezips_df
# Out:
#                  Average List Price  Listing Count              Location  \
# listing_addrzip
# 92091                  16800.000000              2     [Rancho Santa Fe]
# 67340                   5550.000000              3             [Dearing]
# 92029                   4445.000000              4           [Escondido]
# 92155                   4350.000000              1           [San Diego]
# 92152                   3595.000000              1           [San Diego]
# 92013                   3464.545455             11            [Carlsbad]
# 92093                   3264.928571             28            [La Jolla]
# 92147                   3017.894737             57           [San Diego]
# 92007                   3011.600000             25  [Cardiff By The Sea]
# 92014                   2993.403226             62             [Del Mar]
# 92075                   2952.962963             27        [Solana Beach]
# 92052                   2886.166667             36           [Oceanside]
# 92198                   2785.100000             10           [San Diego]
# 92178                   2719.857143              7            [Coronado]
# 92130                   2718.368421             19           [San Diego]
# 92092                   2700.000000              1            [La Jolla]
# 92024                   2699.627907             43           [Encinitas]
# 92121                   2690.652778             72           [San Diego]
# 92008                   2680.608696             23            [Carlsbad]
# 91914                   2636.875000              8         [Chula Vista]
#
#                 Zip Code              Location (Zip)
# listing_addrzip
# 92091            [92091]     [Rancho Santa Fe 92091]
# 67340            [67340]             [Dearing 67340]
# 92029            [92029]           [Escondido 92029]
# 92155            [92155]           [San Diego 92155]
# 92152            [92152]           [San Diego 92152]
# 92013            [92013]            [Carlsbad 92013]
# 92093            [92093]            [La Jolla 92093]
# 92147            [92147]           [San Diego 92147]
# 92007            [92007]  [Cardiff By The Sea 92007]
# 92014            [92014]             [Del Mar 92014]
# 92075            [92075]        [Solana Beach 92075]
# 92052            [92052]           [Oceanside 92052]
# 92198            [92198]           [San Diego 92198]
# 92178            [92178]            [Coronado 92178]
# 92130            [92130]           [San Diego 92130]
# 92092            [92092]            [La Jolla 92092]
# 92024            [92024]           [Encinitas 92024]
# 92121            [92121]           [San Diego 92121]
# 92008            [92008]            [Carlsbad 92008]
# 91914            [91914]         [Chula Vista 91914]

# %%
summary_stats_lowpricezips_df
# Out:
#                  Average List Price  Listing Count          Location Zip Code  \
# listing_addrzip
# 91987                    500.000000              1          [Tecate]  [91987]
# 91905                    557.000000              1       [Boulevard]  [91905]
# 92386                    600.000000              1       [Sugarloaf]  [92386]
# 92036                    912.500000              2          [Julian]  [92036]
# 92070                    950.000000              2    [Santa Ysabel]  [92070]
# 91908                   1025.000000              2          [Bonita]  [91908]
# 89173                   1137.000000              2       [Las Vegas]  [89173]
# 91935                   1287.500000              2           [Jamul]  [91935]
# 92003                   1300.000000              2         [Bonsall]  [92003]
# 92132                   1300.000000              2       [San Diego]  [92132]
# 92106                   1445.000000              1       [San Diego]  [92106]
# 91901                   1450.000000              1          [Alpine]  [91901]
# 92030                   1473.666667             45       [Escondido]  [92030]
# 92135                   1525.000000              1       [San Diego]  [92135]
# 92022                   1576.904762             84        [El Cajon]  [92022]
# 92020                   1624.090909             33        [El Cajon]  [92020]
# 92105                   1632.333333             24       [San Diego]  [92105]
# 92069                   1650.000000              1      [San Marcos]  [92069]
# 91932                   1657.600000             20  [Imperial Beach]  [91932]
# 91903                   1667.346154             26          [Alpine]  [91903]
#
#                          Location (Zip)
# listing_addrzip
# 91987                    [Tecate 91987]
# 91905                 [Boulevard 91905]
# 92386                 [Sugarloaf 92386]
# 92036                    [Julian 92036]
# 92070              [Santa Ysabel 92070]
# 91908                    [Bonita 91908]
# 89173                 [Las Vegas 89173]
# 91935                     [Jamul 91935]
# 92003                   [Bonsall 92003]
# 92132                 [San Diego 92132]
# 92106                 [San Diego 92106]
# 91901                    [Alpine 91901]
# 92030                 [Escondido 92030]
# 92135                 [San Diego 92135]
# 92022                  [El Cajon 92022]
# 92020                  [El Cajon 92020]
# 92105                 [San Diego 92105]
# 92069                [San Marcos 92069]
# 91932            [Imperial Beach 91932]
# 91903                    [Alpine 91903]

# %%
summary_stats_mostlistingszips_df
# Out:
#                  Average List Price  Listing Count       Location Zip Code  \
# listing_addrzip
# 92033                   1863.086486            370    [Escondido]  [92033]
# 92187                   2558.008658            231    [San Diego]  [92187]
# 92122                   2373.035556            225    [San Diego]  [92122]
# 91943                   2001.601896            211      [La Mesa]  [91943]
# 92054                   1998.804348            184    [Oceanside]  [92054]
# 92079                   2266.211111            180   [San Marcos]  [92079]
# 91909                   1735.672727            165  [Chula Vista]  [91909]
# 92085                   1987.187500            160        [Vista]  [92085]
# 92056                   2034.875817            153    [Oceanside]  [92056]
# 92112                   2472.178571            140    [San Diego]  [92112]
# 92018                   2349.441176            136     [Carlsbad]  [92018]
# 92116                   2100.194175            103    [San Diego]  [92116]
# 92103                   2196.990196            102    [San Diego]  [92103]
# 91911                   1998.500000             98  [Chula Vista]  [91911]
# 91910                   1941.350515             97  [Chula Vista]  [91910]
# 92108                   2394.677419             93    [San Diego]  [92108]
# 92110                   2547.021739             92    [San Diego]  [92110]
# 92107                   2266.213483             89    [San Diego]  [92107]
# 92109                   2364.853933             89    [San Diego]  [92109]
# 92084                   1804.523256             86        [Vista]  [92084]
#
#                       Location (Zip)
# listing_addrzip
# 92033              [Escondido 92033]
# 92187              [San Diego 92187]
# 92122              [San Diego 92122]
# 91943                [La Mesa 91943]
# 92054              [Oceanside 92054]
# 92079             [San Marcos 92079]
# 91909            [Chula Vista 91909]
# 92085                  [Vista 92085]
# 92056              [Oceanside 92056]
# 92112              [San Diego 92112]
# 92018               [Carlsbad 92018]
# 92116              [San Diego 92116]
# 92103              [San Diego 92103]
# 91911            [Chula Vista 91911]
# 91910            [Chula Vista 91910]
# 92108              [San Diego 92108]
# 92110              [San Diego 92110]
# 92107              [San Diego 92107]
# 92109              [San Diego 92109]
# 92084                  [Vista 92084]

# %%
mean_highprices = []
locations_highprices = []
zipcodes_highprices = []

for m in summary_stats_highpricezips_df['Average List Price']:
    mean_highprices.append(m)
for l in summary_stats_highpricezips_df['Location (Zip)']:
    locations_highprices.append(l)        
for z in summary_stats_highpricezips_df['Zip Code']:
    zipcodes_highprices.append(z)

# %%
x_axis = np.arange(0, len(locations_highprices))
tick_locations = []
for x in x_axis:
    tick_locations.append(x)
    
fig, ax = plt.subplots(figsize=(12,8)) # set the size that you'd like 
fig.subplots_adjust(bottom=0.4)
for item in ([ax.title, ax.xaxis.label, ax.yaxis.label] +
             ax.get_xticklabels() + ax.get_yticklabels()):
    item.set_fontsize(14)
fig.suptitle('Top 20 Highest Average Rental Listing Price', fontsize=20)

plt.xlabel("Zip Code")
plt.ylabel("Average Rental Listing Price ($)")

plt.xlim(-0.75, len(locations_highprices)-.25)
plt.ylim(0, max(mean_highprices) + 1000)

plt.bar(x_axis,mean_highprices, facecolor="#097392", alpha=0.75, align="center")
plt.xticks(tick_locations, locations_highprices, rotation=90)
plt.savefig("../resources/images/fig01_top20averageprice.png")
plt.show()

# %%
mean_lowprices = []
locations_lowprices = []
zipcodes_lowprices = []

for m in summary_stats_lowpricezips_df['Average List Price']:
    mean_lowprices.append(m)
for l in summary_stats_lowpricezips_df['Location (Zip)']:
    locations_lowprices.append(l)        
for z in summary_stats_lowpricezips_df['Zip Code']:
    zipcodes_lowprices.append(z)

# %%
x_axis = np.arange(0, len(locations_lowprices))
tick_locations = []
for x in x_axis:
    tick_locations.append(x)
    
fig, ax = plt.subplots(figsize=(12,8)) # set the size that you'd like 
fig.subplots_adjust(bottom=0.4)
for item in ([ax.title, ax.xaxis.label, ax.yaxis.label] +
             ax.get_xticklabels() + ax.get_yticklabels()):
    item.set_fontsize(14)
fig.suptitle('Lowest Average Rental Listing Price', fontsize=20)

plt.xlabel("Location and Zip Code")
plt.ylabel("Average Rental Listing Price ($)")

plt.xlim(-0.75, len(locations_lowprices)-.25)
plt.ylim(0, max(mean_lowprices) + 1000)

plt.bar(x_axis, mean_lowprices, facecolor=config.orangered, alpha=0.75, align="center")
plt.xticks(tick_locations, locations_lowprices, rotation=90)
plt.savefig("../resources/images/fig02_bottom20averageprice.png")
plt.show()

# %%
"""
# Histogram Plot of Data
plt.subplot(2, 1, 2)
plt.hist(population, 20, density=True, alpha=0.7, label="population")
plt.hist(sample, 20, density=True, alpha=0.7, label="sample")
plt.axvline(population.mean(), color='k', linestyle='dashed', linewidth=1)
plt.axvline(sample.mean(), color='k', linestyle='dashed', linewidth=1)
plt.legend()  
"""
# Out:
# '\n# Histogram Plot of Data\nplt.subplot(2, 1, 2)\nplt.hist(population, 20, density=True, alpha=0.7, label="population")\nplt.hist(sample, 20, density=True, alpha=0.7, label="sample")\nplt.axvline(population.mean(), color=\'k\', linestyle=\'dashed\', linewidth=1)\nplt.axvline(sample.mean(), color=\'k\', linestyle=\'dashed\', linewidth=1)\nplt.legend()  \n'

# %%
listprices = []

for lp in base_df['listing_price']: 
    listprices.append(lp)

print(f'Total number of list prices analyzed: {len(listprices)}')  
print(f'Average listing price accross all zip codes: ${round(list_average(listprices),0)}')  
print(f'Highest list price all zip codes ${max(listprices)}')
print(f'Lowest list price all zip codes ${min(listprices)}')

# %%
# Histogram Plot of Data
fig, ax = plt.subplots(figsize=(10,6)) # set the size that you'd like 
fig.suptitle('Histogram of list prices for all zip codes', fontsize=20)
plt.xlabel("List Price ($)")

plt.subplot(1,1,1)
plt.hist(listprices, 15, density=True, alpha=0.7,color=config.lightgreen, label="Listing Prices (all zip codes)")
plt.axvline(Average(listprices), color='k', linestyle='dashed', linewidth=1)
plt.savefig("../resources/images/fig05_listinghistallzips.png")
plt.legend() 



plt.show
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-df7bcd97cca1> in <module>
#       6 plt.subplot(1,1,1)
#       7 plt.hist(listprices, 15, density=True, alpha=0.7,color=config.lightgreen, label="Listing Prices (all zip codes)")
# ----> 8 plt.axvline(Average(listprices), color='k', linestyle='dashed', linewidth=1)
#       9 plt.savefig("../resources/images/fig05_listinghistallzips.png")
#      10 plt.legend()
#
# NameError: name 'Average' is not defined

# %%
base_df

# %%
# mean, median, variance, standard deviation, and SEM of the listing_price 
zip_count = grouped_zip_df["listing_addrzip"].count()

# Assemble the resulting series into a single summary dataframe.

summary_stats_df = pd.DataFrame(
    {"Zip Listing Count": zip_count,
    "Location": grouped_zip_df["listing_addrlocality"].unique(),
    "Zip Code": grouped_zip_df["listing_addrzip"].unique(),
    "Location (Zip)": grouped_zip_df["listing_addrlocality"].unique() + " " + grouped_zip_df["listing_addrzip"].unique()
    })
summary_stats_df

# %%
listing_92033_df = base_df.loc[base_df['listing_addrzip'] == '92033']
listing_92033_prices = listing_92033_df['listing_price']

len(listing_92033_prices)
print(f'Total number of list prices in 92033 (Encinitas): {len(listing_92033_prices)}')  
print(f'Average listing price accross 92033 (Encinitas): ${round(list_average(listing_92033_prices),0)}')  
print(f'Highest list price in 92033 (Encinitas) ${max(listing_92033_prices)}')
print(f'Lowest list price in 92033 (Encinitas) ${min(listing_92033_prices)}')

# %%
# Histogram Plot of Data
fig, ax = plt.subplots(figsize=(10,6)) # set the size that you'd like 
fig.suptitle('Histogram of list prices 92033 (Encinitas)', fontsize=20)
plt.xlabel("List Price ($)")

plt.subplot(1,1,1)
plt.hist(listing_92033_prices, 15, density=True, alpha=0.7,color=config.lightyellow, label="Listing Prices 92033 (Encinitas)")
plt.axvline(Average(listing_92033_prices), color='k', linestyle='dashed', linewidth=1)
plt.savefig("../resources/images/fig07_listinghist92033zip.png")
plt.legend()  
plt.show
