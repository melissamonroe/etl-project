# %%
import pymongo
import dns
import datetime

# Project defined dependencies
import config
from pprint import pprint
import cl_parser

# %%
# Create the craiglist parser
my_parser = cl_parser.Parser()

# %%
drop_column_name = 'listing_removed'

# %%
message = ''
x = 0
for l in my_parser.listings_collection.find():         
    try:
        doc = my_parser.listings_collection.find_one_and_update(
            {'data_id' : l['data_id']},
            {'$unset':
                {
                    'listing_date': 1
                }
                
            },upsert=True
        )
        print('Unset listing_date ' + l['data_id'])
        x += 1
        
    except:
        message += f'{x}|'
# Out:
# ing_date 7281406043
# Unset listing_date 7281425320
# Unset listing_date 7281425054
# Unset listing_date 7281424798
# Unset listing_date 7281421026
# Unset listing_date 7281420803
# Unset listing_date 7281407689
# Unset listing_date 7281410768
# Unset listing_date 7281382061
# Unset listing_date 7281412724
# Unset listing_date 7281411301
# Unset listing_date 7281409921
# Unset listing_date 7281403436
# Unset listing_date 7281399178
# Unset listing_date 7281398284
# Unset listing_date 7281397859
# Unset listing_date 7281397215
# Unset listing_date 7281397033
# Unset listing_date 7281396710
# Unset listing_date 7281396005
# Unset listing_date 7281386963
# Unset listing_date 7281390359
# Unset listing_date 7281387495
# Unset listing_date 7281386675
# Unset listing_date 7281385829
# Unset listing_date 7281355060
# Unset listing_date 7281382823
# Unset listing_date 7281381154
# Unset listing_date 7281380935
# Unset listing_date 7281380864
# Unset listing_date 7281380733
# Unset listing_date 7281380590
# Unset listing_date 7281380260
# Unset listing_date 7281375363
# Unset listing_date 7281366544
# Unset listing_date 7281372285
# Unset listing_date 7281372133
# Unset listing_date 7281371911
# Unset listing_date 7281371025
# Unset listing_date 7281370836
# Unset listing_date 7281369411
# Unset listing_date 7281368354
# Unset listing_date 7281366303
# Unset listing_date 7281349313
# Unset listing_date 7281362121
# Unset listing_date 7281350918
# Unset listing_date 7281352429
# Unset listing_date 7281350978
# Unset listing_date 7281350805
# Unset listing_date 7281349777
# Unset listing_date 7281349357
# Unset listing_date 7281348799
# Unset listing_date 7281346591
# Unset listing_date 7281346564
# Unset listing_date 7281344336
# Unset listing_date 7281322298
# Unset listing_date 7281339118
# Unset listing_date 7281339045
# Unset listing_date 7281338113
# Unset listing_date 7281336908
# Unset listing_date 7281335474
# Unset listing_date 7272083537
# Unset listing_date 7281332276
# Unset listing_date 7281280850
# Unset listing_date 7281328505
# Unset listing_date 7281327431
# Unset listing_date 7281324669
# Unset listing_date 7281307104
# Unset listing_date 7281319565
# Unset listing_date 7281312343
# Unset listing_date 7281297845
# Unset listing_date 7281292773
# Unset listing_date 7281276164
# Unset listing_date 7281287045
# Unset listing_date 7281277297
# Unset listing_date 7281281110
# Unset listing_date 7281280795
# Unset listing_date 7281195685
# Unset listing_date 7281261135
# Unset listing_date 7281259982
# Unset listing_date 7281251622
# Unset listing_date 7281249892
# Unset listing_date 7281232216
# Unset listing_date 7281235973
# Unset listing_date 7281221838
# Unset listing_date 7281233680
# Unset listing_date 7281233437
# Unset listing_date 7281191763
# Unset listing_date 7281233105
# Unset listing_date 7281232426
# Unset listing_date 7281232073
# Unset listing_date 7281228721
# Unset listing_date 7281223479
# Unset listing_date 7281220443
# Unset listing_date 7281184822
# Unset listing_date 7281202201
# Unset listing_date 7281211247
# Unset listing_date 7281213889
# Unset listing_date 7281210178
# Unset listing_date 7281201303
# Unset listing_date 7281208301
# Unset listing_date 7281205063
# Unset listing_date 7281204719
# Unset listing_date 7281201016
# Unset listing_date 7281202905
# Unset listing_date 7281193631
# Unset listing_date 7281192452
# Unset listing_date 7281183519
# Unset listing_date 7281183013
# Unset listing_date 7281158136
# Unset listing_date 7281177706
# Unset listing_date 7281177454
# Unset listing_date 7281177253
# Unset listing_date 7281177116
# Unset listing_date 7281176966
# Unset listing_date 7281159463
# Unset listing_date 7281157008
# Unset listing_date 7281173235
# Unset listing_date 7281164116
# Unset listing_date 7281162351
# Unset listing_date 7281169883
# Unset listing_date 7281169507
# Unset listing_date 7281164922
# Unset listing_date 7281161720
# Unset listing_date 7281161231
# Unset listing_date 7281160743
# Unset listing_date 7281160615
# Unset listing_date 7281158170
# Unset listing_date 7281151022
# Unset listing_date 7281156027
# Unset listing_date 7281155372
# Unset listing_date 7281155007
# Unset listing_date 7281154622
# Unset listing_date 7281148154
# Unset listing_date 7281146584
# Unset listing_date 7281145179
# Unset listing_date 7281144340
# Unset listing_date 7281137537
# Unset listing_date 7281136005
# Unset listing_date 7281135595
# Unset listing_date 7281135371
# Unset listing_date 7281135057
# Unset listing_date 7281134730
# Unset listing_date 7281134300
# Unset listing_date 7281134100
# Unset listing_date 7281131070
# Unset listing_date 7281130338
# Unset listing_date 7281875524
# Unset listing_date 7281869200
# Unset listing_date 7281863333
# Unset listing_date 7281872411
# Unset listing_date 7281872228
# Unset listing_date 7281868875
# Unset listing_date 7281868570
# Unset listing_date 7281866622
# Unset listing_date 7281857327
# Unset listing_date 7281865110
# Unset listing_date 7281864425
# Unset listing_date 7281864115
# Unset listing_date 7281858060
# Unset listing_date 7281861430
# Unset listing_date 7281860641
# Unset listing_date 7281852785
# Unset listing_date 7281850114
# Unset listing_date 7281856140
# Unset listing_date 7281853926
# Unset listing_date 7281845012
# Unset listing_date 7281852725
# Unset listing_date 7281846953
# Unset listing_date 7281846452
# Unset listing_date 7281845458
# Unset listing_date 7281844719
# Unset listing_date 7281844014
# Unset listing_date 7281838605
# Unset listing_date 7281841680
# Unset listing_date 7281841277
# Unset listing_date 7281841138
# Unset listing_date 7281840540
# Unset listing_date 7281838436
# Unset listing_date 7281837547
# Unset listing_date 7281825820
# Unset listing_date 7281834257
# Unset listing_date 7281833521
# Unset listing_date 7281821856
# Unset listing_date 7281829390
# Unset listing_date 7281820375
# Unset listing_date 7281823434
# Unset listing_date 7281820225
# Unset listing_date 7281811615
# Unset listing_date 7281816757
# Unset listing_date 7281791225
# Unset listing_date 7281808168
# Unset listing_date 7281797535
# Unset listing_date 7281804970
# Unset listing_date 7281802566
# Unset listing_date 7281762831
# Unset listing_date 7281800766
# Unset listing_date 7281727738
# Unset listing_date 7281795016
# Unset listing_date 7281784919
# Unset listing_date 7281788477
# Unset listing_date 7281788278
# Unset listing_date 7281773218
# Unset listing_date 7281784885
# Unset listing_date 7281784861
# Unset listing_date 7281782496
# Unset listing_date 7281775615
# Unset listing_date 7281764463
# Unset listing_date 7281760092
# Unset listing_date 7281762516
# Unset listing_date 7281760031
# Unset listing_date 7281767254
# Unset listing_date 7281766915
# Unset listing_date 7281758086
# Unset listing_date 7281762080
# Unset listing_date 7281757963
# Unset listing_date 7281760277
# Unset listing_date 7281758069
# Unset listing_date 7281756770
# Unset listing_date 7281729876
# Unset listing_date 7281741330
# Unset listing_date 7281729513
# Unset listing_date 7281710272
# Unset listing_date 7281749799
# Unset listing_date 7281741815
# Unset listing_date 7281744257
# Unset listing_date 7281728221
# Unset listing_date 7281730762
# Unset listing_date 7281740873
# Unset listing_date 7281728453
# Unset listing_date 7281740049
# Unset listing_date 7281739296
# Unset listing_date 7281738626
# Unset listing_date 7281722415
# Unset listing_date 7281736744
# Unset listing_date 7281736371
# Unset listing_date 7281736240
# Unset listing_date 7281736222
# Unset listing_date 7281735128
# Unset listing_date 7281734903
# Unset listing_date 7281734654
# Unset listing_date 7281733414
# Unset listing_date 7281733087
# Unset listing_date 7281728732
# Unset listing_date 7281732679
# Unset listing_date 7281732209
# Unset listing_date 7281730913
# Unset listing_date 7281712500
# Unset listing_date 7281713551
# Unset listing_date 7281729197
# Unset listing_date 7281717991
# Unset listing_date 7281710597
# Unset listing_date 7281724827
# Unset listing_date 7281721184
# Unset listing_date 7281719456
# Unset listing_date 7281710476
# Unset listing_date 7281713948
# Unset listing_date 7281710258
# Unset listing_date 7281708397
# Unset listing_date 7281707354
# Unset listing_date 7281692905
# Unset listing_date 7281702408
# Unset listing_date 7281681944
# Unset listing_date 7281659178
# Unset listing_date 7281695248
# Unset listing_date 7281694366
# Unset listing_date 7281659227
# Unset listing_date 7281694712
# Unset listing_date 7281701286
# Unset listing_date 7281700524
# Unset listing_date 7281659119
# Unset listing_date 7281698800
# Unset listing_date 7281698495
# Unset listing_date 7281880769
# Unset listing_date 7281875789
# Unset listing_date 7281874801
# Unset listing_date 7281874138
# Unset listing_date 7281869248
# Unset listing_date 7281872167
# Unset listing_date 7281865854
# Unset listing_date 7281865590
# Unset listing_date 7281855096
# Unset listing_date 7281849764
# Unset listing_date 7281854325
# Unset listing_date 7281853461
# Unset listing_date 7281853255
# Unset listing_date 7281850923
# Unset listing_date 7281848525
# Unset listing_date 7281845817
# Unset listing_date 7281845399
# Unset listing_date 7281825628
# Unset listing_date 7281826485
# Unset listing_date 7281822855
# Unset listing_date 7281821201
# Unset listing_date 7281820896
# Unset listing_date 7281818336
# Unset listing_date 7281814108
# Unset listing_date 7281813924
# Unset listing_date 7281814285
# Unset listing_date 7281797132
# Unset listing_date 7281796872
# Unset listing_date 7281799364
# Unset listing_date 7281798702
# Unset listing_date 7281797931
# Unset listing_date 7281797091
# Unset listing_date 7281794644
# Unset listing_date 7281784046
# Unset listing_date 7281783713
# Unset listing_date 7281783282
# Unset listing_date 7281778597
# Unset listing_date 7281765933
# Unset listing_date 7281769738
# Unset listing_date 7281767261
# Unset listing_date 7281765755
# Unset listing_date 7281763157
# Unset listing_date 7281760235
# Unset listing_date 7281759702
# Unset listing_date 7281730347
# Unset listing_date 7281746185
# Unset listing_date 7281744163
# Unset listing_date 7281742366
# Unset listing_date 7281742018
# Unset listing_date 7281738999
# Unset listing_date 7281738611
# Unset listing_date 7281734443
# Unset listing_date 7281733951
# Unset listing_date 7281731195
# Unset listing_date 7281722051
# Unset listing_date 7281721611
# Unset listing_date 7281711194
# Unset listing_date 7281714265
# Unset listing_date 7281710993
# Unset listing_date 7281705061
# Unset listing_date 7281698201
# Unset listing_date 7281693264
# Unset listing_date 7281691804
# Unset listing_date 7281682928
# Unset listing_date 7281687995
# Unset listing_date 7281686212
# Unset listing_date 7281685080
# Unset listing_date 7281684872
# Unset listing_date 7281681260
# Unset listing_date 7281670489
# Unset listing_date 7281670679
# Unset listing_date 7281670880
# Unset listing_date 7281671143
# Unset listing_date 7281670294
# Unset listing_date 7281647477
# Unset listing_date 7281652286
# Unset listing_date 7272552572
# Unset listing_date 7281649308
# Unset listing_date 7281637963
# Unset listing_date 7281642786
# Unset listing_date 7281639310
# Unset listing_date 7281616452
# Unset listing_date 7281633738
# Unset listing_date 7274237661
# Unset listing_date 7281633171
# Unset listing_date 7281610039
# Unset listing_date 7281606237
# Unset listing_date 7281571627
# Unset listing_date 7281601856
# Unset listing_date 7281598085
# Unset listing_date 7281597022
# Unset listing_date 7281596714
# Unset listing_date 7281583570
# Unset listing_date 7281581463
# Unset listing_date 7281560045
# Unset listing_date 7281557075
# Unset listing_date 7281556729
# Unset listing_date 7281556529
# Unset listing_date 7281482743
# Unset listing_date 7281477434
# Unset listing_date 7281478540
# Unset listing_date 7281872066
# Unset listing_date 7281879979
# Unset listing_date 7281879724
# Unset listing_date 7281850617
# Unset listing_date 7281878460
# Unset listing_date 7281877959
# Unset listing_date 7281855728
# Unset listing_date 7281873066
# Unset listing_date 7281826070
# Unset listing_date 7281873023
# Unset listing_date 7281865995
# Unset listing_date 7281871955
# Unset listing_date 7281871824
# Unset listing_date 7276464606
# Unset listing_date 7281870888
# Unset listing_date 7281870585
# Unset listing_date 7281846904
# Unset listing_date 7281869473
# Unset listing_date 7281869109
# Unset listing_date 7281861734
# Unset listing_date 7281868982
# Unset listing_date 7281868430
# Unset listing_date 7281863943
# Unset listing_date 7281865204
# Unset listing_date 7281867512
# Unset listing_date 7281866435
# Unset listing_date 7278382030
# Unset listing_date 7281865597
# Unset listing_date 7281865058
# Unset listing_date 7281863721
# Unset listing_date 7281864068
# Unset listing_date 7281863449
# Unset listing_date 7281862480
# Unset listing_date 7281862419
# Unset listing_date 7281861483
# Unset listing_date 7281854209
# Unset listing_date 7281860135
# Unset listing_date 7281859742
# Unset listing_date 7281851334
# Unset listing_date 7281825405
# Unset listing_date 7281798520
# Unset listing_date 7281858308
# Unset listing_date 7279050094
# Unset listing_date 7281857584
# Unset listing_date 7281857462
# Unset listing_date 7281850890
# Unset listing_date 7281856997
# Unset listing_date 7278858899
# Unset listing_date 7278870987
# Unset listing_date 7281855952
# Unset listing_date 7274102769
# Unset listing_date 7274103490
# Unset listing_date 7281854201
# Unset listing_date 7281854078
# Unset listing_date 7281843393
# Unset listing_date 7281796673
# Unset listing_date 7281792708
# Unset listing_date 7281852760
# Unset listing_date 7281852690
# Unset listing_date 7281852568
# Unset listing_date 7281794803
# Unset listing_date 7281833677
# Unset listing_date 7281823166
# Unset listing_date 7281848427
# Unset listing_date 7281848150
# Unset listing_date 7281835546
# Unset listing_date 7281847764
# Unset listing_date 7281847574
# Unset listing_date 7278356139
# Unset listing_date 7281847406
# Unset listing_date 7281847388
# Unset listing_date 7281843663
# Unset listing_date 7278355694
# Unset listing_date 7281846657
# Unset listing_date 7281834547
# Unset listing_date 7281814346
# Unset listing_date 7281837389
# Unset listing_date 7281779287
# Unset listing_date 7281840395
# Unset listing_date 7281839985
# Unset listing_date 7281833143
# Unset listing_date 7281832512
# Unset listing_date 7281831139
# Unset listing_date 7281823433
# Unset listing_date 7281836180
# Unset listing_date 7281802404
# Unset listing_date 7281835735
# Unset listing_date 7281835615
# Unset listing_date 7281829020
# Unset listing_date 7281834933
# Unset listing_date 7281833884
# Unset listing_date 7281833749
# Unset listing_date 7281816742
# Unset listing_date 7281828628
# Unset listing_date 7281832548
# Unset listing_date 7281825795
# Unset listing_date 7281784321
# Unset listing_date 7281818352
# Unset listing_date 7281829037
# Unset listing_date 7281828153
# Unset listing_date 7281806670
# Unset listing_date 7281828294
# Unset listing_date 7281774557
# Unset listing_date 7281827577
# Unset listing_date 7281827509
# Unset listing_date 7281785454
# Unset listing_date 7281772528
# Unset listing_date 7281825313
# Unset listing_date 7281823282
# Unset listing_date 7281790647
# Unset listing_date 7281821618
# Unset listing_date 7281820497
# Unset listing_date 7281781307
# Unset listing_date 7281802545
# Unset listing_date 7281819423
# Unset listing_date 7281812323
# Unset listing_date 7281765923
# Unset listing_date 7281792930
# Unset listing_date 7281815792
# Unset listing_date 7281815800
# Unset listing_date 7281810000
# Unset listing_date 7281815057
# Unset listing_date 7281814669
# Unset listing_date 7281814193
# Unset listing_date 7281814038
# Unset listing_date 7281813729
# Unset listing_date 7281776376
# Unset listing_date 7281811867
# Unset listing_date 7281811445
# Unset listing_date 7281799608
# Unset listing_date 7281810602
# Unset listing_date 7281799451
# Unset listing_date 7281742157
# Unset listing_date 7281802434
# Unset listing_date 7281774506
# Unset listing_date 7281801510
# Unset listing_date 7281799641
# Unset listing_date 7281808054
# Unset listing_date 7281794029
# Unset listing_date 7281748260
# Unset listing_date 7281805684
# Unset listing_date 7281794158
# Unset listing_date 7281799860
# Unset listing_date 7281799750
# Unset listing_date 7281802851
# Unset listing_date 7281797761
# Unset listing_date 7281788588
# Unset listing_date 7281802320
# Unset listing_date 7281789366
# Unset listing_date 7281801136
# Unset listing_date 7281780749
# Unset listing_date 7281799229
# Unset listing_date 7281795208
# Unset listing_date 7281777073
# Unset listing_date 7281795416
# Unset listing_date 7281794632
# Unset listing_date 7281794498
# Unset listing_date 7281777716
# Unset listing_date 7281793159
# Unset listing_date 7281791771
# Unset listing_date 7281791744
# Unset listing_date 7281791503
# Unset listing_date 7281790786
# Unset listing_date 7281790440
# Unset listing_date 7281866112
# Unset listing_date 7281838373
# Unset listing_date 7281863295
# Unset listing_date 7281865681
# Unset listing_date 7281863950
# Unset listing_date 7281862132
# Unset listing_date 7281861855
# Unset listing_date 7281856053
# Unset listing_date 7281848064
# Unset listing_date 7281846572
# Unset listing_date 7281844330
# Unset listing_date 7281842465
# Unset listing_date 7281836807
# Unset listing_date 7281832128
# Unset listing_date 7281833154
# Unset listing_date 7281831842
# Unset listing_date 7281824682
# Unset listing_date 7281824554
# Unset listing_date 7281801697
# Unset listing_date 7281823420
# Unset listing_date 7281767977
# Unset listing_date 7281813649
# Unset listing_date 7281794551
# Unset listing_date 7281791617
# Unset listing_date 7281790744
# Unset listing_date 7281789642
# Unset listing_date 7281787246
# Unset listing_date 7281774996
# Unset listing_date 7281779256
# Unset listing_date 7281778999
# Unset listing_date 7281778864
# Unset listing_date 7281778729
# Unset listing_date 7281754311
# Unset listing_date 7281768076
# Unset listing_date 7281765982
# Unset listing_date 7281741366
# Unset listing_date 7281758647
# Unset listing_date 7281749684
# Unset listing_date 7281720789
# Unset listing_date 7281751010
# Unset listing_date 7281750528
# Unset listing_date 7281750512
# Unset listing_date 7281748374
# Unset listing_date 7281722285
# Unset listing_date 7281743776
# Unset listing_date 7281723896
# Unset listing_date 7281734493
# Unset listing_date 7281723128
# Unset listing_date 7281733651
# Unset listing_date 7281729092
# Unset listing_date 7281729603
# Unset listing_date 7281723400
# Unset listing_date 7281722317
# Unset listing_date 7281721833
# Unset listing_date 7281720300
# Unset listing_date 7281719625
# Unset listing_date 7281715577
# Unset listing_date 7281719245
# Unset listing_date 7281713044
# Unset listing_date 7281715338
# Unset listing_date 7281713792
# Unset listing_date 7281704759
# Unset listing_date 7281698101
# Unset listing_date 7281701192
# Unset listing_date 7281701021
# Unset listing_date 7281695642
# Unset listing_date 7281690271
# Unset listing_date 7281692707
# Unset listing_date 7281666381
# Unset listing_date 7281684536
# Unset listing_date 7281689985
# Unset listing_date 7281688609
# Unset listing_date 7281688262
# Unset listing_date 7281688232
# Unset listing_date 7281681331
# Unset listing_date 7281676622
# Unset listing_date 7281675789
# Unset listing_date 7281673745
# Unset listing_date 7281672611
# Unset listing_date 7281670854
# Unset listing_date 7281667582
# Unset listing_date 7281667048
# Unset listing_date 7281664789
# Unset listing_date 7281662735
# Unset listing_date 7281662573
# Unset listing_date 7281651085
# Unset listing_date 7281652239
# Unset listing_date 7281657320
# Unset listing_date 7281657264
# Unset listing_date 7281656054
# Unset listing_date 7281650670
# Unset listing_date 7281650423
# Unset listing_date 7281649698
# Unset listing_date 7281642702
# Unset listing_date 7281647202
# Unset listing_date 7281641059
# Unset listing_date 7281646093
# Unset listing_date 7281645447
# Unset listing_date 7281644772
# Unset listing_date 7281642227
# Unset listing_date 7281641694
# Unset listing_date 7281641422
# Unset listing_date 7281641355
# Unset listing_date 7281641304
# Unset listing_date 7281640043
# Unset listing_date 7281639335
# Unset listing_date 7281638786
# Unset listing_date 7281638479
# Unset listing_date 7281633809
# Unset listing_date 7281626371
# Unset listing_date 7281623903
# Unset listing_date 7281623036
# Unset listing_date 7281620514
# Unset listing_date 7281619617
# Unset listing_date 7281618679
# Unset listing_date 7281602554
# Unset listing_date 7281496593
# Unset listing_date 7281496223
# Unset listing_date 7281497785
# Unset listing_date 7281496039
# Unset listing_date 7281497600
# Unset listing_date 7281496372
# Unset listing_date 7281497113
# Unset listing_date 7281496923
# Unset listing_date 7281497359
# Unset listing_date 7281495651
# Unset listing_date 7281496781
# Unset listing_date 7281495157
# Unset listing_date 7281474173
